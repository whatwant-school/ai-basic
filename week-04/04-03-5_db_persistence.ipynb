# %%
import pandas as pd

# %% [markdown]
# ### Load database
# #### Example from
# - https://www.dataquest.io/blog/python-pandas-databases/

# %%
# !wget https://github.com/TEAMLAB-Lecture/AI-python-connect/raw/master/codes/ch_3/part-2/data/flights.db
# Out:
# --2023-02-16 17:12:20--  https://github.com/TEAMLAB-Lecture/AI-python-connect/raw/master/codes/ch_3/part-2/data/flights.db
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/TEAMLAB-Lecture/AI-python-connect/master/codes/ch_3/part-2/data/flights.db [following]
# --2023-02-16 17:12:20--  https://raw.githubusercontent.com/TEAMLAB-Lecture/AI-python-connect/master/codes/ch_3/part-2/data/flights.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5415936 (5.2M) [application/octet-stream]
# Saving to: ‘flights.db’
#
# flights.db          100%[===================>]   5.17M  --.-KB/s    in 0.08s
#
# 2023-02-16 17:12:20 (65.9 MB/s) - ‘flights.db’ saved [5415936/5415936]

# %%
import sqlite3

conn = sqlite3.connect("./flights.db")
cur = conn.cursor()
cur.execute("select * from airlines limit 5;")
results = cur.fetchall()
results
# Out:
# [(0, '1', 'Private flight', '\\N', '-', None, None, None, 'Y'),
#  (1, '2', '135 Airways', '\\N', None, 'GNL', 'GENERAL', 'United States', 'N'),
#  (2, '3', '1Time Airline', '\\N', '1T', 'RNX', 'NEXTIME', 'South Africa', 'Y'),
#  (3,
#   '4',
#   '2 Sqn No 1 Elementary Flying Training School',
#   '\\N',
#   None,
#   'WYT',
#   None,
#   'United Kingdom',
#   'N'),
#  (4, '5', '213 Flight Unit', '\\N', None, 'TFU', None, 'Russia', 'N')]

# %% [markdown]
# #### Data loading using pandas from DB

# %%
df_airplines = pd.read_sql_query("select * from airlines;", conn)
df_airplines
# Out:
#       index     id                                          name  \
# 0         0      1                                Private flight
# 1         1      2                                   135 Airways
# 2         2      3                                 1Time Airline
# 3         3      4  2 Sqn No 1 Elementary Flying Training School
# 4         4      5                               213 Flight Unit
# ...     ...    ...                                           ...
# 6043   6043  19828                                    Vuela Cuba
# 6044   6044  19830                                 All Australia
# 6045   6045  19831                                    Fly Europa
# 6046   6046  19834                                   FlyPortugal
# 6047   6047  19845                          FTI Fluggesellschaft
#
#               alias  iata  icao     callsign         country active
# 0                \N     -  None         None            None      Y
# 1                \N  None   GNL      GENERAL   United States      N
# 2                \N    1T   RNX      NEXTIME    South Africa      Y
# 3                \N  None   WYT         None  United Kingdom      N
# 4                \N  None   TFU         None          Russia      N
# ...             ...   ...   ...          ...             ...    ...
# 6043     Vuela Cuba    6C   6CC         None            Cuba      Y
# 6044  All Australia    88   8K8         None       Australia      Y
# 6045           None    ER   RWW         None           Spain      Y
# 6046           None    PO   FPT  FlyPortugal        Portugal      Y
# 6047           None  None   FTI         None         Germany      N
#
# [6048 rows x 9 columns]

# %%
df_airports = pd.read_sql_query("select * from airports;", conn)
df_routes = pd.read_sql_query("select * from routes;", conn)

# %%
df_airplines
# Out:
#       index     id                                          name  \
# 0         0      1                                Private flight
# 1         1      2                                   135 Airways
# 2         2      3                                 1Time Airline
# 3         3      4  2 Sqn No 1 Elementary Flying Training School
# 4         4      5                               213 Flight Unit
# ...     ...    ...                                           ...
# 6043   6043  19828                                    Vuela Cuba
# 6044   6044  19830                                 All Australia
# 6045   6045  19831                                    Fly Europa
# 6046   6046  19834                                   FlyPortugal
# 6047   6047  19845                          FTI Fluggesellschaft
#
#               alias  iata  icao     callsign         country active
# 0                \N     -  None         None            None      Y
# 1                \N  None   GNL      GENERAL   United States      N
# 2                \N    1T   RNX      NEXTIME    South Africa      Y
# 3                \N  None   WYT         None  United Kingdom      N
# 4                \N  None   TFU         None          Russia      N
# ...             ...   ...   ...          ...             ...    ...
# 6043     Vuela Cuba    6C   6CC         None            Cuba      Y
# 6044  All Australia    88   8K8         None       Australia      Y
# 6045           None    ER   RWW         None           Spain      Y
# 6046           None    PO   FPT  FlyPortugal        Portugal      Y
# 6047           None  None   FTI         None         Germany      N
#
# [6048 rows x 9 columns]

# %%
df_airports.head()
# Out:
#    index id                        name          city           country code  \
# 0      0  1                      Goroka        Goroka  Papua New Guinea  GKA
# 1      1  2                      Madang        Madang  Papua New Guinea  MAG
# 2      2  3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU
# 3      3  4                      Nadzab        Nadzab  Papua New Guinea  LAE
# 4      4  5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM
#
#    icao   latitude   longitude altitude offset dst              timezone
# 0  AYGA  -6.081689  145.391881     5282     10   U  Pacific/Port_Moresby
# 1  AYMD  -5.207083    145.7887       20     10   U  Pacific/Port_Moresby
# 2  AYMH  -5.826789  144.295861     5388     10   U  Pacific/Port_Moresby
# 3  AYNZ  -6.569828  146.726242      239     10   U  Pacific/Port_Moresby
# 4  AYPY  -9.443383   147.22005      146     10   U  Pacific/Port_Moresby

# %%
df_routes.head()
# Out:
#    index airline airline_id source source_id dest dest_id codeshare stops  \
# 0      0      2B        410    AER      2965  KZN    2990      None     0
# 1      1      2B        410    ASF      2966  KZN    2990      None     0
# 2      2      2B        410    ASF      2966  MRV    2962      None     0
# 3      3      2B        410    CEK      2968  KZN    2990      None     0
# 4      4      2B        410    CEK      2968  OVB    4078      None     0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# ### Pandas persistence
# #### install
# - conda install openpyxl
# - conda install XlsxWriter
# - see more http://xlsxwriter.readthedocs.io/working_with_pandas.html

# %%
# !pip install openpyxl
# !pip install XlsxWriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.8/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl) (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: XlsxWriter in /usr/local/lib/python3.8/dist-packages (3.0.8)

# %%
writer = pd.ExcelWriter('./df_routes.xlsx', engine='xlsxwriter')
df_routes.to_excel(writer, sheet_name='Sheet1')

# %%
df_routes.to_pickle("./df_routes.pickle")

# %%
df_routes_pickle = pd.read_pickle("./df_routes.pickle")
df_routes_pickle.head()
# Out:
#    index airline airline_id source source_id dest dest_id codeshare stops  \
# 0      0      2B        410    AER      2965  KZN    2990      None     0
# 1      1      2B        410    ASF      2966  KZN    2990      None     0
# 2      2      2B        410    ASF      2966  MRV    2962      None     0
# 3      3      2B        410    CEK      2968  KZN    2990      None     0
# 4      4      2B        410    CEK      2968  OVB    4078      None     0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %%
df_routes_pickle.describe()
# Out:
#               index
# count  67663.000000
# mean   33831.000000
# std    19532.769969
# min        0.000000
# 25%    16915.500000
# 50%    33831.000000
# 75%    50746.500000
# max    67662.000000
